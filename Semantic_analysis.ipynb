# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import math
import operator

# %%
pd.options.display.max_colwidth = 250

# %%
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 42.5 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 48.1 MB/s
# ...
#      |████████████████████████████████| 182 kB 51.0 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 33.0 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=2f346f7a7cf02450fe8d21ad2a9e02b150fb8ac3cab15bc9e2a917c2dc57f646
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence-transformers
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-mpnet-base-v2')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
sentences = []

for chapter in range(1, 19):

  # analyzing chapters in which number of verses match across translations
  if chapter==1 or chapter==2 or chapter==4 or chapter==6 or chapter==13 or chapter==14 or chapter==18:      
    continue

  eknath_easwaran_chapter= pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/Sentiment Predictions/eknath easwaran/chapter ' + str(chapter))
  mahatma_gandhi_chapter = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/Sentiment Predictions/mahatma gandhi/chapter ' + str(chapter))
  purohit_swami_chapter = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/Sentiment Predictions/shri purohit swami/chapter '+ str(chapter))
  google_translator_chapter = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/Translated_slokas/predicted sentiment/chapter '+ str(chapter))
  sentence1 = eknath_easwaran_chapter['Tweet'].tolist()
  sentence2 = mahatma_gandhi_chapter['Tweet'].tolist()
  sentence3 = purohit_swami_chapter['Tweet'].tolist()
  sentence4 = google_translator_chapter['Tweet'].tolist()

  sentences.append(sentence1)
  sentences.append(sentence2)
  sentences.append(sentence3)
  sentences.append(sentence4)

  # print('Chapter - ', str(chapter), ' ', len(eknath_easwaran_chapter))

sentence_new = []
for i in range(0, len(sentences)):
  for j in range(0, len(sentences[i])):
    sentence_new.append(sentences[i][j])

sentence_embeddings = model.encode(sentence_new)

# %%
sentence_embeddings.shape
# Out:
# (1412, 768)

# %%
df = pd.DataFrame(columns=['Chapter', 'Verse', 'Eknath Easwaran','Mahatma Gandhi','Shri Swami Purohit','Google Translator' , 'Easwaran - Google','Gandhi - Google','Purohit - Google'])

# %%
i = 0
j = 43
k = 86
l = 129
verse = 1

for i in range(0, 43):

  easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
  gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
  purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

  dict1 = {'Chapter': [3], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

  i+=1
  j+=1
  k+=1
  l+=1
  verse+=1

  df_new = pd.DataFrame(dict1)
  df = pd.concat([df, df_new], ignore_index = True)

# print(sentence_new[0])
# print(sentence_new[43])
# print(sentence_new[86])
# print('\n')

df.tail()
# Out:
#    Chapter Verse  \
# 38       3    39
# 39       3    40
# 40       3    41
# 41       3    42
# 42       3    43
#
#                                                                                                                                   Eknath Easwaran  \
# 38                                            hidden, Arjuna, by this unquenchable fire for self-satisfaction, the inveterate enemy of the wise.
# 39                        Selfish desire is found in the senses, mind, and intellect, misleading them and burying the understanding in delusion.
# 40                Fight with all your strength, Arjuna! Controlling your senses, conquer your enemy, the destroyer of knowledge and realization.
# 41  The senses are higher than the body, the mind higher than the senses; above the mind is the intellect, and above the intellect is the Atman.
# ...

# %%
i = 129
j = 158
k = 187
l = 216
verse = 1

for i in range(129, 158):

   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [5], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#    Chapter Verse  \
# 67       5    25
# 68       5    26
# 69       5    27
# 70       5    28
# 71       5    29
#
#                                                                                                                                                                                                                                  Eknath Easwaran  \
# 67  O descendant of Bharata who are attached to the activities of the Supreme Personality of Godhead, who is not attached to the activities of the demigods, one should perform the rituals of acquiring the planetary activities of the Lord. .
# 68                                                                                                                         A learned person should not cause differences in intelligence to those who are ignorant and associated with actions .
# ...

# %%
i = 216
j = 246
k = 276
l = 306
verse = 1

for i in range(216, 246):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [7], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 97        7    26
# 98        7    27
# 99        7    28
# 100       7    29
# 101       7    30
#
#                                                                                                                                                                                                            Eknath Easwaran  \
# 97    Having abandoned the fruit of action, he wins eternal peace. Others unacquainted with spirituality, led by desire and clinging to the benefit which they think will follow their actions, become entangled in them.
# 98                                       Mentally renouncing all actions, the self-controlled soul enjoys bliss in this body, the city of the nine gates, neither doing anything himself nor causing anything to be done.
# ...

# %%
i = 306
j = 334
k = 362
l = 390
verse = 1

for i in range(306, 334):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [8], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 125       8    24
# 126       8    25
# 127       8    26
# 128       8    27
# 129       8    28
#
#                                                                                                                                                               Eknath Easwaran  \
# 125                        Know that all the manifestations of the three gunas, sattva, rajas, and tamas,  proceed from none but Me; yet I am not in them; they are in Me.
# 126                                 Befogged by these manifestations of the three gunas, the entire world fails to  recognize Me, the imperishable, as transcending them.
# 127                            For this My divine delusive mystery made up of the three gunas is hard to  pierce; but those who make Me their sole refuge pierce the veil.
# 128    The deluded evil-doers, lowest of men, do not see refuge in Me; for, by  reason of this delusive mystery, they are bereft of knowledge and given to  devilish ways.
# ...

# %%
i = 390
j = 424
k = 458
l = 492
verse = 1

for i in range(390, 424):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [9], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 159       9    30
# 160       9    31
# 161       9    32
# 162       9    33
# 163       9    34
#
#                                                                                                                                                                            Eknath Easwaran  \
# 159    Remembering me at the time of death, close down the doors of the senses and place the mind in the heart. Then, while absorbed in meditation, focus all energy upwards to the head.
# 160                         Repeating in this state the divine name, the syllable Om that represents the changeless Brahman, you will go forth from the body and attain the supreme goal.
# 161                                                     I am easily attained by the person who always remembers me and is attached to nothing else. Such a person is a true yogi, Arjuna.
# ...

# %%
i = 492
j = 534
k = 576
l = 618
verse = 1

for i in range(492, 534):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [10], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 201      10    38
# 202      10    39
# 203      10    40
# 204      10    41
# 205      10    42
#
#                                                                                                                                      Eknath Easwaran  \
# 201    Under my watchful eye the laws of nature take their course. Thus is the world set in motion; thus the animate and the inanimate are created.
# 202                                         The immature do not look beyond physical appearances to see my true nature as the Lord of all creation.
# 203        The knowledge of such deluded people is empty; their lives are fraught with disaster and evil, and their work and hopes are all in vain.
# 204      But truly great souls seek my divine nature. They worship me with a one-pointed mind, having realized that I am the eternal source of all.
# ...

# %%
i = 618
j = 673
k = 728
l = 783
verse = 1

for i in range(618, 673):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [11], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 256      11    51
# 257      11    52
# 258      11    53
# 259      11    54
# 260      11    55
#
#                                                                                                                                                              Eknath Easwaran  \
# 256                                      The great sages and seers  Narada, Asita, Devala, and Vyasa too  have acclaimed you thus; now you have declared it to me yourself.
# 257                                      Now, O Krishna, I believe that everything you have told me is divine truth. O Lord, neither gods nor demons know your real nature.
# 258                 Indeed, you alone know yourself, O supreme spirit. You are the source of being and the master of every creature, God of gods, the Lord of the universe.
# 259                                                      Tell me all your divine attributes, leaving nothing unsaid. Tell me of the glories with which you fill the cosmos.
# ...

# %%
i = 783
j = 803
k = 823
l = 843
verse = 1

for i in range(783, 803):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [12], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 276      12    16
# 277      12    17
# 278      12    18
# 279      12    19
# 280      12    20
#
#                                                                                                                                                      Eknath Easwaran  \
# 276               O Lord, how can I meditate on You, who are always contemplating You, O Lord? You are to be contemplated by me, O Supreme Personality of Godhead. .
# 277                                                          O Lord Janārdana, please explain to me more of myself in detail, for I am very much pleased with me.  ॥
# 278                      O best of the Kurus, I shall now explain to you the divine opulences of my own self-realized souls. I shall now explain to you in detail. .
# 279          O Gudakesha, I am the Self, and I am situated in the hearts of all living beings. I am the beginning, the middle and the end of all living entities.  ॥
# ...

# %%
i = 843
j = 863
k = 883
l = 903
verse = 1

for i in range(843, 863):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [15], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 296      15    16
# 297      15    17
# 298      15    18
# 299      15    19
# 300      15    20
#
#                                                                                                                                                                                                                                                Eknath Easwaran  \
# 296                                                                                                                      SANJAYA:  Having heard these words, Arjuna trembled in fear. With joined palms he bowed before Krishna and addressed him stammering.
# 297                                                      ARJUNA:  O Krishna, it is right that the world delights and rejoices in your praise, that all the saints and sages bow down to you and all evil flees before you to the far corners of the universe.
# ...

# %%
i = 903
j = 927
k = 951
l = 975
verse = 1

for i in range(903, 927):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [16], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 320      16    20
# 321      16    21
# 322      16    22
# 323      16    23
# 324      16    24
#
#                                                                                                                                                                                                                                              Eknath Easwaran  \
# 320                                                          Therefore, I prostrate myself before You, and beseech Your grace, O Lord  adorable! As father with son, as comrade with comrade, so should You bear,  beloved Lord, with me, Your loved one.
# 321                                                                     I am filled with joy to see what never was seen before, and yet my heart is  oppressed with fear. Show me that original form of Yours, O Lord! Be gracious,  Krishna, O Krishna!
# ...

# %%
i = 975
j = 1003
k = 1031
l = 1059
verse = 1

for i in range(975, 1003):
   easwaran_google = cosine_similarity([sentence_embeddings[i]], [sentence_embeddings[l]])[0][0]
   gandhi_google = cosine_similarity([sentence_embeddings[j]], [sentence_embeddings[l]])[0][0]
   purohit_google = cosine_similarity([sentence_embeddings[k]], [sentence_embeddings[l]])[0][0]

   dict1 = {'Chapter': [17], 'Verse': verse, 'Eknath Easwaran': [sentence_new[i]], 'Mahatma Gandhi': [sentence_new[j]], 'Shri Swami Purohit': [sentence_new[k]],'Google Translator' : [sentence_new[l]],
                'Easwaran - Google': [easwaran_google], 'Gandhi - Google': [gandhi_google], 'Purohit - Google': [purohit_google]}

   i+=1
   j+=1
   k+=1
   l+=1
   verse+=1

   df_new = pd.DataFrame(dict1)
   df = pd.concat([df, df_new], ignore_index = True)


df.tail()
# Out:
#     Chapter Verse  \
# 348      17    24
# 349      17    25
# 350      17    26
# 351      17    27
# 352      17    28
#
#                                                                                                             Eknath Easwaran  \
# 348                                                                                 The eyes of many speeches were several.
# 349                                                          many divine ornaments were adorned with many divine ornaments.
# 350  If the sun rises simultaneously in the heavens in the sky, the great soul will be like the light of the great soul.  ॥
# 351      At that time the Pāṇḍavas saw the entire universe in the body of the demigods in various parts of the universe.  ॥
# 352                Then Arjuna, overjoyed in astonishment, Arjuna bowed his head to the god and spoke with folded hands.  ॥
#
# ...

# %%
df.shape
# Out:
# (353, 9)

# %%
df.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/cosine_similarity.csv')

# %%
maximum_difference_easwaran_google = df.loc[(df['Easwaran - Google'] < 0.5)]
# maximum_difference_easwaran_gandhi.to_csv('/content/drive/MyDrive/religious_texts/semantic analysis/all-mpnet-base-v2/easwaran gandhi.csv')
maximum_difference_easwaran_google
# Out:
#     Chapter Verse  \
# 2         3     3
# 5         3     6
# 8         3     9
# 9         3    10
# 11        3    12
# ..      ...   ...
# 348      17    24
# 349      17    25
# 350      17    26
# 351      17    27
# 352      17    28
#
#                                                                                                                                                                                                                   Eknath Easwaran  \
# 2                                       KRISHNA:  At the beginning of time I declared two paths for the pure heart: jnana yoga, the contemplative path of spiritual wisdom, and karma yoga, the active path of selfless service.
# 5                                                                                               Those who abstain from action while allowing the mind to dwell on sensual pleasure cannot be called sincere spiritual aspirants.
# ...

# %%
maximum_difference = maximum_difference_easwaran_google.loc[(maximum_difference_easwaran_google['Gandhi - Google'] < 0.5) & 
                                                                  (maximum_difference_easwaran_google['Purohit - Google'] < 0.5)]

maximum_difference
# Out:
#     Chapter Verse  \
# 17        3    18
# 24        3    25
# 27        3    28
# 31        3    32
# 50        5     8
# ..      ...   ...
# 347      17    23
# 348      17    24
# 349      17    25
# 350      17    26
# 351      17    27
#
#                                                                                                                                                                           Eknath Easwaran  \
# 17                                                                                 They have nothing to gain or lose by any action; neither people nor things can affect their security.
# 24                                                           The ignorant work for their own profit, Arjuna; the wise work for the welfare of the world, without thought for themselves.
# 27   But the illumined man or woman understands the domain of the gunas and is not attached. Such people know that the gunas interact with each other; they do not claim to be the doer.
# ...

# %%
maximum_difference_easwaran_google.shape
# Out:
# (306, 9)

# %%
maximum_difference_gandhi_google = df.loc[(df['Gandhi - Google'] < 0.6)]
# maximum_difference_gandhi_purohit.to_csv('/content/drive/MyDrive/religious_texts/semantic analysis/all-mpnet-base-v2/gandhi purohit.csv')
maximum_difference_gandhi_google
# Out:
#     Chapter Verse  \
# 0         3     1
# 1         3     2
# 4         3     5
# 10        3    11
# 11        3    12
# ..      ...   ...
# 347      17    23
# 348      17    24
# 349      17    25
# 350      17    26
# 351      17    27
#
#                                                                                                                                                                                   Eknath Easwaran  \
# 0                                                                     ARJUNA:  O Krishna, you have said that knowledge is greater than action; why then do you ask me to wage this terrible war?
# 1                                                                                                                Your advice seems inconsistent. Give me one path to follow to the supreme good.
# ...

# %%
maximum_difference_purohit_easwaran = df.loc[(df['Purohit - Google'] < 0.7)]
maximum_difference_purohit_easwaran.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/purohit_google.csv')

# %%
df.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/cosine similarity - sklearn.csv')

# %%
sentence_embeddings.shape
# Out:
# (1412, 768)

# %%
df.head(2)
# Out:
#   Chapter Verse  \
# 0       3     1
# 1       3     2
#
#                                                                                                                Eknath Easwaran  \
# 0  ARJUNA:  O Krishna, you have said that knowledge is greater than action; why then do you ask me to wage this terrible war?
# 1                                             Your advice seems inconsistent. Give me one path to follow to the supreme good.
#
#                                                                                                                                                                  Mahatma Gandhi  \
# 0                                   If, O Krishna, you hold that the attitude of detachment is superior to  action, then why, O Krishna, do you urge me to dreadful action?
# 1    You do seem to confuse my understanding with perplexing speech; tell  me, therefore, in no uncertain voice, that alone whereby I may attain salvation.   The Lord Said:
#
# ...

# %%
df['total'] = df['Easwaran - Google'] + df['Gandhi - Google'] + df['Purohit - Google']
df.head(2)
# Out:
#   Chapter Verse  \
# 0       3     1
# 1       3     2
#
#                                                                                                                Eknath Easwaran  \
# 0  ARJUNA:  O Krishna, you have said that knowledge is greater than action; why then do you ask me to wage this terrible war?
# 1                                             Your advice seems inconsistent. Give me one path to follow to the supreme good.
#
#                                                                                                                                                                  Mahatma Gandhi  \
# 0                                   If, O Krishna, you hold that the attitude of detachment is superior to  action, then why, O Krishna, do you urge me to dreadful action?
# 1    You do seem to confuse my understanding with perplexing speech; tell  me, therefore, in no uncertain voice, that alone whereby I may attain salvation.   The Lord Said:
#
# ...

# %%
df['max sum'] = df.groupby(['Chapter'])['total'].transform('max')
df.head(2)
# Out:
#   Chapter Verse  \
# 0       3     1
# 1       3     2
#
#                                                                                                                Eknath Easwaran  \
# 0  ARJUNA:  O Krishna, you have said that knowledge is greater than action; why then do you ask me to wage this terrible war?
# 1                                             Your advice seems inconsistent. Give me one path to follow to the supreme good.
#
#                                                                                                                                                                  Mahatma Gandhi  \
# 0                                   If, O Krishna, you hold that the attitude of detachment is superior to  action, then why, O Krishna, do you urge me to dreadful action?
# 1    You do seem to confuse my understanding with perplexing speech; tell  me, therefore, in no uncertain voice, that alone whereby I may attain salvation.   The Lord Said:
#
# ...

# %%
df_max_sum = df.loc[(df['max sum'] == df['total'])]
df_max_sum
# Out:
#     Chapter Verse  \
# 12        3    13
# 57        5    15
# 84        7    13
# 122       8    21
# 160       9    31
# 178      10    15
# 226      11    21
# 279      12    19
# 299      15    19
# 323      16    23
# 352      17    28
#
#                                                                                                                                                                                                                                                Eknath Easwaran  \
# 12                                                                                            The spiritually minded, who eat in the spirit of service, are freed from all their sins; but the selfish, who prepare food for their own satisfaction, eat sin.
# ...

# %%
df_max_sum.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/max_sum_in_every_chapter.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/cosine_similarity.csv')

df.drop(['Unnamed: 0'], axis=1, inplace=True)
df = df.loc[(df.Chapter ==12)]
#df.fillna(0)

print('Easwaran - Google mean - ', df['Easwaran - Google'].mean())
print('Easwaran - Google std - ', df['Easwaran - Google'].std())
print('\n')

print('Gandhi -Google mean - ', df['Gandhi - Google'].mean())
print('Gandhi - Google std - ', df['Gandhi - Google'].std())
print('\n')

print('Purohit -Google mean - ', df['Purohit - Google'].mean())
print('Purohit - Google std - ', df['Purohit - Google'].std())
# Out:
# Easwaran - Google mean -  0.3492900679999999
# Easwaran - Google std -  0.12241128321224799
#
#
# Gandhi -Google mean -  0.34668753799999996
# Gandhi - Google std -  0.11790183597378802
#
#
# Purohit -Google mean -  0.4005645285
# Purohit - Google std -  0.15949796957377868

# %%
df['total'] = df['Easwaran - Google'] + df['Gandhi - Google'] + df['Purohit - Google']
df.head()
# Out:
#      Chapter  Verse  \
# 261       12      1
# 262       12      2
# 263       12      3
# 264       12      4
# 265       12      5
#
#                                                                                                                                                                 Eknath Easwaran  \
# 261                                              I do not know the origin of the demigods, nor the great sages, for I am the origin of all the demigods and the great sages.  ॥
# 262  He who knows Me as the origin of the universe and the Supreme Personality of Godhead, who is not deluded by the Supreme Personality of Godhead, is freed from all sins.  ॥
# 263                                                 Intelligence, knowledge, non-delusion, forgiveness, truthfulness, restraint, happiness, pain, birth, fear and fearlessness.
# ...

# %%
df['min sum'] = df.groupby(['Chapter'])['total'].transform('min')

df.head()
# Out:
#      Chapter  Verse  \
# 261       12      1
# 262       12      2
# 263       12      3
# 264       12      4
# 265       12      5
#
#                                                                                                                                                                 Eknath Easwaran  \
# 261                                              I do not know the origin of the demigods, nor the great sages, for I am the origin of all the demigods and the great sages.  ॥
# 262  He who knows Me as the origin of the universe and the Supreme Personality of Godhead, who is not deluded by the Supreme Personality of Godhead, is freed from all sins.  ॥
# 263                                                 Intelligence, knowledge, non-delusion, forgiveness, truthfulness, restraint, happiness, pain, birth, fear and fearlessness.
# ...

# %%
df_least_sum = df.loc[(df['min sum'] == df['total'])]

df_least_sum.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/least_sum_in_every_chapter.csv')

# %%
df_least_sum
# Out:
#      Chapter  Verse  \
# 275       12     15
#
#                                                                                                                   Eknath Easwaran  \
# 275  Please explain to me the entire universe with all the splendors of self-realized souls by which you pervade these worlds.  ॥
#
#                                                                                                                                                                                Mahatma Gandhi  \
# 275  I am the effulgence of the effulgence of the effulgence of those who are deceived by the gambling I am the victory I am the determination I am the mode of goodness among the virtuous .
#
#                                                                                                                   Shri Swami Purohit  \
# 275   Filled with amazement, his hair standing on end in ecstasy, he bowed before the Lord with joined palms and spoke these words.
#
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/cosine_similarity.csv')
maximum_difference = df.loc[(df['Easwaran - Google']<0.5) & (df['Gandhi - Google'] < 0.5) & (df['Purohit - Google'] < 0.5)]
maximum_difference
# Out:
#      Unnamed: 0  Chapter  Verse  \
# 17           17        3     18
# 24           24        3     25
# 27           27        3     28
# 31           31        3     32
# 50           50        5      8
# ..          ...      ...    ...
# 347         347       17     23
# 348         348       17     24
# 349         349       17     25
# 350         350       17     26
# 351         351       17     27
#
#                                                                                                                                                                           Eknath Easwaran  \
# 17                                                                                 They have nothing to gain or lose by any action; neither people nor things can affect their security.
# 24                                                           The ignorant work for their own profit, Arjuna; the wise work for the welfare of the world, without thought for themselves.
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/cosine_similarity.csv')

# %%
df_mean_easwaran_google = df.groupby('Chapter')['Easwaran - Google'].mean().reset_index()
df_mean_gandhi_google = df.groupby('Chapter')['Gandhi - Google'].mean().reset_index()
df_mean_purohit_google = df.groupby('Chapter')['Purohit - Google'].mean().reset_index()

df_std_easwaran_google = df.groupby('Chapter')['Easwaran - Google'].std().reset_index()
df_std_gandhi_google = df.groupby('Chapter')['Gandhi - Google'].std().reset_index()
df_std_purohit_google = df.groupby('Chapter')['Purohit - Google'].std().reset_index()

# %%
df_std_easwaran_google
# Out:
#     Chapter  Easwaran - Google
# 0         3           0.156070
# 1         5           0.082462
# 2         7           0.094236
# 3         8           0.086423
# 4         9           0.108353
# 5        10           0.120574
# 6        11           0.117747
# 7        12           0.122411
# 8        15           0.134868
# 9        16           0.126245
# 10       17           0.076853

# %%
df_std_purohit_google
# Out:
#     Chapter  Purohit - Google
# 0         3          0.148168
# 1         5          0.132575
# 2         7          0.232234
# 3         8          0.103867
# 4         9          0.113447
# 5        10          0.118167
# 6        11          0.107604
# 7        12          0.159498
# 8        15          0.128604
# 9        16          0.127995
# 10       17          0.128009

# %%
df_std_gandhi_google
# Out:
#     Chapter  Gandhi - Google
# 0         3         0.120009
# 1         5         0.186504
# 2         7         0.099771
# 3         8         0.098215
# 4         9         0.102527
# 5        10         0.092587
# 6        11         0.104648
# 7        12         0.117902
# 8        15         0.142475
# 9        16         0.088998
# 10       17         0.115205

# %%
df_mean_easwaran_google
# Out:
#     Chapter  Easwaran - Google
# 0         3           0.517857
# 1         5           0.345699
# 2         7           0.350357
# 3         8           0.359814
# 4         9           0.333023
# 5        10           0.334715
# 6        11           0.363438
# 7        12           0.349290
# 8        15           0.405333
# 9        16           0.382626
# 10       17           0.300703

# %%
df_mean_purohit_google
# Out:
#     Chapter  Purohit - Google
# 0         3          0.582847
# 1         5          0.609761
# 2         7          0.556089
# 3         8          0.343455
# 4         9          0.361091
# 5        10          0.368119
# 6        11          0.376197
# 7        12          0.400565
# 8        15          0.390944
# 9        16          0.374426
# 10       17          0.354208

# %%
df_mean_gandhi_google
# Out:
#     Chapter  Gandhi - Google
# 0         3         0.586533
# 1         5         0.510344
# 2         7         0.346340
# 3         8         0.382554
# 4         9         0.350272
# 5        10         0.382764
# 6        11         0.381641
# 7        12         0.346688
# 8        15         0.372722
# 9        16         0.414596
# 10       17         0.334055

# %%
df_std_easwaran_google['Easwaran - Google'].mean()
# Out:
# 0.11147643184155656

# %%
df_std_purohit_google['Purohit - Google'].mean()
# Out:
# 0.1363788845911706

# %%
df_std_gandhi_google['Gandhi - Google'].mean()
# Out:
# 0.11534920722596981

# %%
# !pip install keybert
from keybert import KeyBERT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 237 kB 28.9 MB/s
# ...
#      |████████████████████████████████| 51 kB 6.3 MB/s
# ...
#   Created wheel for keybert: filename=keybert-0.7.0-py3-none-any.whl size=23800 sha256=fc7db6049bbc9f1355855ffae246249d1df5cedc3c47a4a09efd0d78580793d1
#   Stored in directory: /root/.cache/pip/wheels/6c/bc/8b/a51bee77aec33895e6c8c236144b4cc10875659c4d2c80f070
# Successfully built keybert
# ...

# %%
kw_model = KeyBERT(model = 'all-mpnet-base-v2')

# %%
####### METHODOLOGY FOR OBTAINING KEYWORDS

# We encode verses using the MPNet-base model to compute the verse by verse semantic similarity. 
# We use the MPNet-base model for extraction of keywords (using KeyBERT) from all chapters. 
# However, given the constraint in the MPNet-base model that number of tokens should not exceed 384, it would not be possible to encode large chapters directly. 
# Hence, we propose a method to overcome this limitation by breaking each chapter into paragraphs of 15 verses. 
# We include 3 verses from the previous paragraph into the current paragraph to retain some context and maintain continuity. 
# For example, in the first paragraph, verses 1-15 are included, and in the second paragraph verses 13-27, then 25-39, and so on.  
# We keep the top 20 keywords because keywords that have a lower similarity score in the original paragraph may be more relevant when the entire paragraph is considered.
 
# Next, we extract the keywords for all paragraphs i with 20 candidate keywords of paragraph j such that i!=j. 
# For each keyword, we add up its cosine similarity score across paragraphs. 
# Finally, we obtain the top 10 keywords having the highest cumulative scores. 
# The key idea here is that if a term is a keyword in a certain paragraph, it also needs to be sufficiently close to other paragraphs in the higher dimensional vector space
# to qualify as a keyword for the entire chapter. 
# We use MMR with a diversity value of 0.5 to prevent the selection of similar meaning keywords.


top_n = 20
final_df = pd.DataFrame()

for chapter in range(1, 19):
  df = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/Translated_slokas/predicted sentiment/chapter '+ str(chapter))
  #df= pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/Sentiment Predictions/mahatma gandhi/chapter ' + str(chapter))
  df = df.drop(['Unnamed: 0', 'Official report'], axis=1)

  score_list = []
  text_list = []
  string_list = []
  keyword_score_map = {}
  keyword_count_map = {}

  for i in range(math.ceil(df.shape[0]/15)):

    if i==0:
      text = ' '.join(df[0:15].Tweet)

    else:
      if df.shape[0] >= 15*(i+1) - 3:
        text = ' '.join(df[(15*i - 3):(15*(i+1)-3)].Tweet)

      else:
        text = ' '.join(df[(15*i-3):df.shape[0]].Tweet)

    list1 = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words='english', top_n = top_n, use_mmr=True, diversity=0.5)
    score_list.append(list1)
    text_list.append(text)

    # print(text)
    # print(list1)

    for jj in range(0, top_n):
      # print('keyword - score ', score_list[0][jj])
      # print('keyword ', score_list[0][jj][0])
      # print('score ', score_list[0][jj][1])

      keyword = score_list[0][jj][0]
      string_list.append(keyword)
      keyword_score_map[keyword] = 0
      keyword_count_map[keyword] = 0

  for ii in range(math.ceil(df.shape[0]/15)):
    for jj in range(math.ceil(df.shape[0]/15)):
      # if chapter==12 or chapter==15 or ii!=jj:

        list2 = kw_model.extract_keywords(text_list[jj], candidates=string_list[top_n*ii : top_n*(ii+1)], keyphrase_ngram_range=(1, 1), stop_words='english', top_n = top_n,
                                          use_mmr=True, diversity=0.3)
        #print(chapter , df.shape[0])
        for kk in range(0, len(list2)):
         # if not list2[kk][0]:
          #  break
          #print(list2[kk][0])
          keyword = list2[kk][0]
          keyword_score = list2[kk][1]
          keyword_score_map[keyword]+=keyword_score
          keyword_count_map[keyword]+=1


  keyword_score_map = dict( sorted(keyword_score_map.items(), key=operator.itemgetter(1),reverse=True))      # sort in descending order according to scores
  keyword_df = pd.DataFrame(keyword_score_map.items(), columns=['Keyword', 'Score'])                         # convert dictionary to dataframe
  keyword_df = keyword_df[:10]                                                                               # TOP 10 KEYWORDS most relevant to text 
  keyword_df['Chapter'] = chapter
  keyword_df['Author'] = 'Google Translator'

  final_df = pd.concat([final_df, keyword_df], axis=0)

final_df
# Out:
#         Keyword   Score  Chapter             Author
# 0        arjuna  7.9260        1  Google Translator
# 1   dhṛtarāṣṭra  5.6120        1  Google Translator
# 2        battle  4.9512        1  Google Translator
# 3   charioteers  3.3168        1  Google Translator
# 4         dyāsa  2.6628        1  Google Translator
# ..          ...     ...      ...                ...
# 5        senses  3.7662       18  Google Translator
# 6      renounce  2.7978       18  Google Translator
# 7      delusion  2.5776       18  Google Translator
# 8    sacrifices  2.5278       18  Google Translator
# 9          fear  2.3514       18  Google Translator
#
# [180 rows x 4 columns]

# %%
final_df.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/google_keywords.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/Google_keyword.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.drop_duplicates(subset='Keyword', keep='last', inplace=True)
onlykey = df.loc[(df['Author'] == 'Google Translator')]
onlykey=onlykey['Keyword']
onlykey
# Out:
# 1      dhratarashtra
# 2             battle
# 3        charioteers
# 4              dyasa
# 7               sake
#            ...
# 175           senses
# 176         renounce
# 177         delusion
# 178       sacrifices
# 179             fear
# Name: Keyword, Length: 105, dtype: object

# %%
onlykey.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/onlykey.tsv', sep='\t', index=None, header=None)

# %%
chapter_12 = final_df.loc[(final_df['Chapter'] == 15)]
chapter_12
# Out:
#      Keyword   Score  Chapter             Author
# 0      vedas  1.7496       15  Google Translator
# 1    godhead  1.5788       15  Google Translator
# 2   entities  1.2612       15  Google Translator
# 3   universe  1.2188       15  Google Translator
# 4  knowledge  1.0428       15  Google Translator
# 5       body  0.9134       15  Google Translator
# 6    nourish  0.8264       15  Google Translator
# 7    eternal  0.6714       15  Google Translator
# 8   perceive  0.5876       15  Google Translator
# 9   ancients  0.4842       15  Google Translator

# %%
keyword_score_map = dict( sorted(keyword_score_map.items(), key=operator.itemgetter(1),reverse=True))

# %%
df = pd.DataFrame(keyword_score_map.items(), columns=['Keyword', 'Score'])

# %%
df[:10]
# Out:
#         Keyword    Score
# 0        arjuna  10.3764
# 1  renunciation   7.0056
# 2        living   5.0796
# 3     described   4.8228
# 4       godhead   4.6542
# 5        senses   3.7662
# 6      renounce   2.7978
# 7      delusion   2.5776
# 8    sacrifices   2.5278
# 9          fear   2.3514

# %%
import numpy as np
from tqdm import tqdm
from typing import List, Union, Tuple
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# !pip install keybert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 237 kB 26.2 MB/s
# ...
#      |████████████████████████████████| 51 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 74.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 58.1 MB/s
# ...
#      |████████████████████████████████| 182 kB 79.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 51.5 MB/s
# ...
#   Created wheel for keybert: filename=keybert-0.7.0-py3-none-any.whl size=23800 sha256=ac42a09d91c45b5e89c3f1a57b8f1dda5692b2c669b4fceef7a5092f492222fe
#   Stored in directory: /root/.cache/pip/wheels/6c/bc/8b/a51bee77aec33895e6c8c236144b4cc10875659c4d2c80f070
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=7a6abcf259fb6fc1372df404fb31fa4b9c638fbf9b7ff4bca95b2560e2f6f5b9
# ...

# %%
# !pip install keybert==0.7.0

# %%
from keybert import KeyBERT
# KeyBERT
from keybert._mmr import mmr
from keybert._maxsum import max_sum_distance
from keybert._highlight import highlight_document
from keybert.backend._utils import select_backend

# %%
model = KeyBERT(model = 'all-mpnet-base-v2')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
model

# %%
df = pd.read_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/Semantic Analysis Results/KeyBERT/shri_purohit_swami.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.drop_duplicates(subset='Keyword', keep='last', inplace=True)
df
# Out:
#             Keyword    Score  Chapter              Author
# 2        duryodhana   4.2736        1  Shri Purohit Swami
# 3          generals   3.7944        1  Shri Purohit Swami
# 4           chariot   3.7908        1  Shri Purohit Swami
# 5            bowmen   3.6540        1  Shri Purohit Swami
# 6           valiant   3.4804        1  Shri Purohit Swami
# ..              ...      ...      ...                 ...
# 175  relinquishment  10.1544       18  Shri Purohit Swami
# 176          desire   8.8344       18  Shri Purohit Swami
# 177        renounce   7.8690       18  Shri Purohit Swami
# 178        forgoing   7.2534       18  Shri Purohit Swami
# 179             act   5.4372       18  Shri Purohit Swami
#
# [113 rows x 4 columns]

# %%
candidates = df['Keyword'].tolist()

# %%
candidates
# Out:
# ['duryodhana',
#  'generals',
#  'chariot',
#  'bowmen',
#  'valiant',
#  'die',
#  'trumpets',
#  'commanded',
#  'compassion',
#  'endure',
#  'battle',
#  'kill',
#  'profess',
#  'bheeshma',
#  'away',
#  'refraining',
#  'consciously',
#  'duty',
#  'yoga',
#  'nourish',
#  'reincarnate',
#  'materialism',
#  'changeless',
#  'ancestors',
#  'births',
#  'meditating',
#  'praise',
#  'divine',
#  'sin',
#  'perceives',
#  'spirituality',
#  'meditation',
#  'celibacy',
#  'purification',
#  'renounces',
#  'virtuous',
#  'vow',
#  'sage',
#  'spiritual',
#  'righteousness',
#  'natures',
#  'unto',
#  'consciousness',
#  'eternity',
#  'mysticism',
#  'souls',
#  'multitude',
#  'immovable',
#  'beings',
#  'mankind',
#  'holiest',
#  'progenitors',
#  'contentment',
#  'omnipresent',
#  'universe',
#  'behold',
#  'embraced',
#  'radiance',
#  'powers',
#  'petal',
#  'devotee',
#  'worship',
#  'meditate',
#  'verily',
#  'realise',
#  'attention',
#  'devotion',
# ...

# %%
doc,candidate_embeddings = model.extract_embeddings(candidates)

# %%
print(len(candidate_embeddings))
print(len(candidate_embeddings[0]))
# Out:
# 113
# 768

# %%
candidate_embeddings
# Out:
# array([[-0.00571294,  0.03313369, -0.01764511, ...,  0.01239058,
#          0.04599014, -0.02001391],
#        [-0.017692  ,  0.11096726, -0.04223696, ...,  0.05520196,
#          0.01838507, -0.00521855],
#        [ 0.03293337,  0.00913427, -0.03127398, ...,  0.02151289,
#         -0.04312754, -0.02665976],
#        ...,
#        [-0.00420476,  0.06491704, -0.0065593 , ...,  0.0080807 ,
#          0.00508294, -0.01001293],
#        [ 0.01612801, -0.0735716 , -0.01101758, ...,  0.00219575,
#         -0.03896737,  0.0096657 ],
#        [-0.02084935, -0.02647869, -0.02503866, ...,  0.02810897,
#         -0.03670445, -0.03136148]], dtype=float32)

# %%
candidate_embeddings = pd.DataFrame(candidate_embeddings)
candidate_embeddings.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/purohit_keywordsall.tsv', sep='\t', index=None, header=None)

# %%
df.to_csv('/content/drive/MyDrive/github/sentimentanalysis_bhagavadgita-main/SM_RESULTS/purohit_metadata.tsv',  index=False, sep='\t')

# %%
import numpy as np
# !pip install scikit-learn==0.21.3
from sklearn.datasets import load_digits
from scipy.spatial.distance import pdist
#from sklearn.manifold.t_sne import _joint_probabilities
from scipy import linalg
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import squareform
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 2)

# %%
tsne = TSNE(perplexity=30)
X_embedded = tsne.fit_transform(candidate_embeddings)

# %%
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], legend='full')
plt.xlabel(xlabel='T-SNE dimension 1')
plt.ylabel(ylabel='T-SNE dimension 2')

plt.show()
